# %% [markdown]
# Section 14.2:  Filtering

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from skimage.color import rgb2gray
from skimage import io

A=io.imread('photo.jpeg'); 
Abw = rgb2gray(A); 
B=Abw+0.5*np.random.randn(600,800)
Bt=np.fft.fft2(B)
Bts=fftshift(Bt)

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(2, 2, 1); ax.imshow(Abw)
ax = fig.add_subplot(2, 2, 2); ax.imshow(B)
ax = fig.add_subplot(2, 2, 3); ax.imshow(np.log(abs(Bts)))

# %%
# step filter
Fs=np.zeros((600,800))
width=50
mask=np.ones((2*width+1,2*width+1))
Fs[301-width:301+width+1,401-width:401+width+1]=mask
Btsf=np.multiply(Bts,Fs)
Btf=fftshift(Btsf)
Bf=np.fft.ifft2(Btf)

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(2, 2, 1); ax.imshow(np.log(abs(Btsf)))
ax = fig.add_subplot(2, 2, 2); ax.imshow(np.real(Bf))
#ax = fig.add_subplot(2, 2, 3); ax.imshow(np.log(abs(Bts)))
# Out:
# /var/folders/pj/yfkyv_g53vs0x1hvqg2gfk1c0000gn/T/ipykernel_13340/3658386588.py:11: RuntimeWarning: divide by zero encountered in log
#   ax = fig.add_subplot(2, 2, 1); ax.imshow(np.log(abs(Btsf)))

# %%
n=200
x=np.linspace(0,2*np.pi,n)
f=np.exp(-2*(x-np.pi)*(x-np.pi))*np.cos(3*x)
ft=np.fft.fft(f)
ftp=fftshift(abs(ft))

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(2, 2, 1); ax.plot(x,f)
ax = fig.add_subplot(2, 2, 2); ax.plot(x,ftp)

# differentiate
